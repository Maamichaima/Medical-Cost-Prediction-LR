# %%
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = [8,5]
plt.rcParams['font.size'] =14
plt.rcParams['font.weight']= 'bold'
# plt.style.use('seaborn-whitegrid')

# %%
df = pd.read_csv("./insurance.csv");
print(f"num of rows and colums dataset ==> {df.shape}")
# Out:
# num of rows and colums dataset ==> (1338, 7)

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19     NaN  27.900         0    yes        NaN  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
sns.lmplot(df, x="bmi", y="charges", aspect=2, height=6)
plt.title('charges vs bmi')
# Out:
# Text(0.5, 1.0, 'charges vs bmi')

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
plt.figure(figsize=(12, 4))
print(df.isnull())
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Missing value in the dataset');
plt.show()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
numerical_cols = ['age', 'bmi', 'children', 'charges']
df_numerical = df[numerical_cols]

corr = df_numerical.corr()

plt.figure(figsize=(9, 7))
sns.heatmap(corr, cmap = 'Wistia', annot= True);
plt.title('Matrice de Corrélation des Variables Numériques')
plt.show()

# %%
# from sklearn.preprocessing import LabelEncoder

# # Encoder sex, smoker, region
# df['sex'] = LabelEncoder().fit_transform(df['sex'])      # male=1, female=0
# df['smoker'] = LabelEncoder().fit_transform(df['smoker'])  # yes=1, no=0
# df['region'] = LabelEncoder().fit_transform(df['region'])  # 4 régions
